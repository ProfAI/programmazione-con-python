# %% [markdown]
# # Esercizi con le eccezioni
#
# ## 1. Vettori Reloaded
# Durante la nostra esercitazione con le classi abbiamo realizzato una classe per rappresentare vettori, in più metodi abbiamo verificato che la lunghezza di due vettori fosse uguale. Rimpiazziamo l'if utilizzato in questi casi con un assert.

# %%
class Vector():

    def __init__(self, values):
        self.values = values

        
    def __getitem__(self, i):
      return self.values[i]


    def __repr__(self) :
       return str(self.values)


    def __add__(self, vector):
        
      assert(len(self.values)==len(vector.values)), "I vettori hanno dimensioni diverse"
    
      list_sum = []

      for val1, val2 in zip(self.values, vector.values):
        list_sum.append(val1+val2)

      return Vector(list_sum)


    def __sub__(self, vector):

      assert(len(self.values)==len(vector.values)), "I vettori hanno dimensioni diverse"

      list_sum = []

      for val1, val2 in zip(self.values, vector.values):
        list_sum.append(val1-val2)

      return Vector(list_sum)


    def __eq__(self, vector):

      assert(len(self.values)==len(vector.values)), "I vettori hanno dimensioni diverse"

      for val1, val2 in zip(self.values, vector.values):
        if(val1 != val2):
          return False
      return True


    def __mul__(self, vector):
      return self.dot(vector)


    def sum(self):
      
      v_sum = 0

      for v in self.values:
        v_sum+=v

      return v_sum


    def dot(self, vector):

      assert(len(self.values)==len(vector.values)), "I vettori hanno dimensioni diverse"

      prod = 0

      for val1, val2 in zip(self.values, vector.values):
        prod+=val1*val2
      
      return prod


    def norm(self):
      return self.dot(self)**(1/2)



v1 = Vector([1, 2, 3])
print(v1)
print(v1[0])
print(v1.sum())

v2 = Vector([2, 4, 6])
print(v1 + v2)
print(v2 - v1)

print(v1==v1)
print(v1==v2)

print(v1*v2)

v3 = Vector([10, 20, 30, 40])
print(v1*v3)

print(v3.norm())
# Out:
# [1, 2, 3]
# 1
# 6
# [3, 6, 9]
# [1, 2, 3]
# True
# False
# 28
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-12b606f473d2> in <module>
#      93
#      94 v3 = Vector([10, 20, 30, 40])
# ---> 95 print(v1*v3)
#      96
#      97 print(v3.norm())
#
# <ipython-input-5-12b606f473d2> in __mul__(self, vector)
#      48
#      49     def __mul__(self, vector):
# ---> 50       return self.dot(vector)
#      51
#      52
#
# <ipython-input-5-12b606f473d2> in dot(self, vector)
#      63     def dot(self, vector):
#      64
# ---> 65       assert(len(self.values)==len(vector.values)), "I vettori hanno dimensioni diverse"
#      66
#      67       prod = 0
#
# AssertionError: I vettori hanno dimensioni diverse

# %% [markdown]
# ## 2. Calcolatrice

# %%
def calculator(a, b, op):
    if(op=="+"):
        return a+b
    elif(op=="-"):
        return a-b
    elif(op=="*"):
        return a*b
    elif(op=="/"):
         try:
            return a/b
         except ZeroDivisionError:
            print("Non puoi dividere per 0")

a, b, op = None, None, None

while(a==None):
    try:
        a = int(input("Inserisci il primo numero: "))
    except ValueError:
        print("Numero non valido")

while(b==None):
    try:
        b = int(input("Inserisci il secondo numero: "))
    except ValueError:
        print("Numero non valido")

while(op!=None):
    op = input("Inserisci l'operatore: ")
    assert(op in ["-","+","*","/"]), "Operatore non valido"

print(calculator(a,b,op))
# Out:
# Inserisci il primo numero: A
# Numero non valido
# Inserisci il primo numero:
# Numero non valido
# Inserisci il primo numero: 1
# Inserisci il secondo numero: +
# Numero non valido
# Inserisci il secondo numero: 2
# Inserisci l'operatore: sa
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     884             try:
# --> 885                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     886             except Exception:
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\jupyter_client\session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\zmq\sugar\socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq\backend\cython\socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-6175fe58c482> in <module>
#      27
#      28
# ---> 29 op = input("Inserisci l'operatore: ")
#      30 assert(op in ["-","+","*","/"]), "Operatore non valido"
#      31
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858             self._parent_ident,
#     859             self._parent_header,
# --> 860             password=False,
#     861         )
#     862
#
# ~\AppData\Local\Programs\Python\Python37-32\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     888             except KeyboardInterrupt:
#     889                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 890                 raise KeyboardInterrupt
#     891             else:
#     892                 break
#
# KeyboardInterrupt:
